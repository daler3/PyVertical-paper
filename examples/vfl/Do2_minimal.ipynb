# %% [markdown]
# # Data Owner 2
#
# Controls right half of images

# %%
from uuid import uuid4

import torch
from torchvision import datasets
from torchvision import transforms

import syft as sy

# %%
import syft as sy
duet = sy.duet(loopback=True)
# Out:
# 🎤  🎸  ♪♪♪ Starting Duet ♫♫♫  🎻  🎹
#
# ♫♫♫ > DISCLAIMER: Duet is an experimental feature currently in beta.
# ♫♫♫ > Use at your own risk.
#
#
#     > ❤️ Love Duet? Please consider supporting our community!
#     > https://github.com/sponsors/OpenMined
#
# ♫♫♫ > Punching through firewall to OpenGrid Network Node at:
# ♫♫♫ > http://ec2-18-216-8-163.us-east-2.compute.amazonaws.com:5000
# ♫♫♫ >
# ♫♫♫ > ...waiting for response from OpenGrid Network...
# ♫♫♫ > DONE!
#
# ♫♫♫ > STEP 1: Send the following code to your Duet Partner!
#
# import syft as sy
# duet = sy.join_duet(loopback=True)
#
# ♫♫♫ > Connecting...
#
# ♫♫♫ > CONNECTED!
#
# ♫♫♫ > DUET LIVE STATUS  *  Objects: 12  Requests: 0   Messages: 4344  Request Handlers: 1

# %%
def split_data(dataset, worker_list=None, n_workers=2):

    if worker_list is None:
        worker_list = list(range(0, n_workers))
            
    #counter to create the index of different data samples
    idx = 0 
    
    #dictionary to accomodate the split data
    dic_single_datasets = {}
    for worker in worker_list: 
        """
        Each value is a list of three elements, to accomodate, in order: 
        - data examples (as tensors)
        - label
        - index 
        """
        dic_single_datasets[worker] = [] 

    """
    Loop through the dataset to split the data and labels vertically across workers. 
    Splitting method from @abbas5253: https://github.com/abbas5253/SplitNN-for-Vertically-Partitioned-Data/blob/master/distribute_data.py
    """
    label_list = []
    index_list = []
    index_list_UUID = []
    for tensor, label in dataset:
        height = tensor.shape[-1]//len(worker_list)
        i = 0
        uuid_idx = uuid4()
        for worker in worker_list[:-1]: 
            dic_single_datasets[worker].append(tensor[:, :, height * i : height * (i + 1)])
            i += 1
            
        #add the value of the last worker / split
        dic_single_datasets[worker_list[-1]].append(tensor[:, :, height * (i) : ])
        label_list.append(torch.Tensor([label]))
        index_list_UUID.append(uuid_idx)
        index_list.append(torch.Tensor([idx]))
        
        idx += 1
        
    return dic_single_datasets, label_list, index_list, index_list_UUID

# %%
transform = transforms.Compose([transforms.ToTensor(),
                              transforms.Normalize((0.5,), (0.5,)),
                              ])
trainset = datasets.MNIST('mnist', download=True, train=True, transform=transform)

# %%
valset = datasets.MNIST('mnist', download=True, train=False, transform=transform)

# %%
img, _, _, _ = split_data(trainset)
img = torch.cat(img[1][:25_000])
img_rshp = img.view(img.shape[0], -1)
print(img_rshp.shape)
# Out:
# torch.Size([5000, 392])

# %%
val_img, _, _, _ = split_data(valset)
val_img = torch.cat(val_img[1][:2_000])
val_img_rshp = val_img.view(val_img.shape[0], -1)
print(val_img_rshp.shape)
# Out:
# torch.Size([1000, 392])
# [2021-02-24T21:38:44.130582+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: ecaf7e7344824930a8e0b556fe34568a>.
# [2021-02-24T21:38:44.138497+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: 6d1d60341f5a4f00a2418b8a71da81ce>.
# [2021-02-24T21:38:45.382562+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: 360fb3b9e7134deabfa07368ad288fa8>.
# [2021-02-24T21:38:46.455412+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: 41cef8d958af4f899ce3bc6487abd84c>.
# [2021-02-24T21:38:46.470825+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: 0446b6649d7f497d92ea208705b684da>.
# [2021-02-24T21:38:47.276942+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: cb227a33b7f34c4a9bb1636141db174f>.
# [2021-02-24T21:38:47.403655+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: d6494c86ccf04995bf7a62663e4e8343>.
# [2021-02-24T21:38:48.304762+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: ef58c3991e5b49f3aa23581d3df69391>.
# [2021-02-24T21:38:48.319838+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: e6fe68beb137486e9e72dae23e8fe5bc>.
# [2021-02-24T21:38:49.087133+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: 3b28214eac8c4eec9eebd22d72673bd9>.
# [2021-02-24T21:38:49.097679+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: e817e1695cc2475997a53257343ebf04>.
# [2021-02-24T21:38:50.225146+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: 1a29448da2bc4cc8b135cdcf66b9de89>.
# [2021-02-24T21:38:50.241383+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: bfb11241c01b4876aea547cf41e27f80>.
# [2021-02-24T21:38:51.275944+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: 429e8c015bbb402c89b832e254667d50>.
# [2021-02-24T21:38:52.316380+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: c567055dcb874e56ac24201acedd4b73>.
# [2021-02-24T21:38:52.330048+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: aa08848cb563480fa3392e82753aac99>.
# [2021-02-24T21:38:53.208333+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: 7adf58a092d342c5a4a600dfab9cab88>.
# [2021-02-24T21:38:53.225064+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: c8cfae8712d848abb9164ed2a104bd85>.
# [2021-02-24T21:38:54.303436+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: 48e25fe051c147918a8581c5016ccb9d>.
# [2021-02-24T21:38:54.316877+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: 411ecc557b5e40e8ab5cfc259ba25c2e>.
# [2021-02-24T21:38:55.245907+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: 12966a120cb54d178c2cc0e6f533c8a0>.
# [2021-02-24T21:38:55.264134+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: 0fc9075710c746ce853583015f5ad822>.
# [2021-02-24T21:38:56.365421+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: 047c657ac31e49acafac91d6a3e4954a>.
# [2021-02-24T21:38:56.404719+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: d337b4501df943e891bb52987787bb1f>.
# [2021-02-24T21:38:57.386832+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: 0aae55b7245044f88e0e4c775cedde23>.
# [2021-02-24T21:38:58.373132+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: 494bdc6fb45640259ca72b3df5179ad3>.
# [2021-02-24T21:38:58.395364+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: 3e398fee201542acaae5743a878eda42>.
# [2021-02-24T21:38:59.591338+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: 422fec022ed74cc6a51aec6fa102ded6>.
# [2021-02-24T21:38:59.641109+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: 225d73c0ad71493dba24fcf388e985a9>.
# [2021-02-24T21:39:00.754797+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: 01245473ef544204b9378ace0f2c8f27>.
# [2021-02-24T21:39:00.767962+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: 81ebd452e58e4999a799fb7f74c9172b>.
# [2021-02-24T21:39:01.578674+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: 58646bbdb11f4e1eb0417a2b2277a313>.
# [2021-02-24T21:39:01.600544+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: df2e3e474fac45278590f4a65f380545>.

# %%
img_rshp.send(duet, searchable=True, tags=["flatten"], description="flattened")
val_img_rshp.send(duet, searchable=True, tags=["flatten_val"], description="flattened")

# %%
duet.requests.add_handler(action="accept", tags=[""])
# Out:
# /home/tom/Documents/OM/PySyft/src/syft/lib/torch/uppercase_tensor.py:45: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   grad = getattr(self.value, "grad", None)
# [2021-02-24T21:10:02.296292+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: 139a926f3c6a4d4b8ea820f309c2316c>.
# [2021-02-24T21:10:02.323316+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __getitem__ error <UID: f6a5d2a03c0349dfb6e7206a880185da> <UID: f6a5d2a03c0349dfb6e7206a880185da>
# [2021-02-24T21:10:02.324160+0000][CRITICAL][logger] <UID: f6a5d2a03c0349dfb6e7206a880185da>
# [2021-02-24T21:10:02.325834+0000][CRITICAL][logger] <UID: f6a5d2a03c0349dfb6e7206a880185da>
# [2021-02-24T21:10:02.326108+0000][CRITICAL][logger] <UID: f6a5d2a03c0349dfb6e7206a880185da>
# [2021-02-24T21:10:02.326372+0000][CRITICAL][logger] <UID: f6a5d2a03c0349dfb6e7206a880185da>
# Exception in callback AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...06a880185da>)>) at /home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_asyncio.py:55
# handle: <Handle AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...06a880185da>)>) at /home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_asyncio.py:55>
# Traceback (most recent call last):
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/nest_asyncio.py", line 199, in run
#     ctx.run(self._callback, *self._args)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_asyncio.py", line 62, in _callback
#     self.emit('error', exc)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_base.py", line 116, in emit
#     self._emit_handle_potential_error(event, args[0] if args else None)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_base.py", line 86, in _emit_handle_potential_error
#     raise error
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/asyncio/tasks.py", line 280, in __step
#     result = coro.send(None)
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 207, in on_message
#     await self.consumer(msg=message)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 909, in async_wrapper
#     retval = await func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 418, in consumer
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 404, in consumer
#     self.recv_immediate_msg_without_reply(msg=_msg)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 461, in recv_immediate_msg_without_reply
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 456, in recv_immediate_msg_without_reply
#     self.node.recv_immediate_msg_without_reply(msg=msg)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 429, in recv_immediate_msg_without_reply
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 400, in recv_immediate_msg_without_reply
#     self.process_message(
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 483, in process_message
#     result = service.process(
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/service/obj_action_service.py", line 26, in process
#     msg.execute_action(node=node, verify_key=verify_key)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/action/run_class_method_action.py", line 111, in execute_action
#     r_arg = node.store[arg.id_at_location]
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/store/store_memory.py", line 74, in __getitem__
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/store/store_memory.py", line 71, in __getitem__
#     return self._objects[key]
# KeyError: <UID: f6a5d2a03c0349dfb6e7206a880185da>
# [2021-02-24T21:10:02.349366+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: ddcdaa644c6743828de72d688b41d78a>.
# [2021-02-24T21:10:03.235155+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __getitem__ error <UID: 6e37d64ef6c24d31870aef5be1709a5a> <UID: 6e37d64ef6c24d31870aef5be1709a5a>
# [2021-02-24T21:10:03.236152+0000][CRITICAL][logger] <UID: 6e37d64ef6c24d31870aef5be1709a5a>
# Exception in callback AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...f5be1709a5a>)>) at /home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_asyncio.py:55
# handle: <Handle AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...f5be1709a5a>)>) at /home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_asyncio.py:55>
# Traceback (most recent call last):
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/nest_asyncio.py", line 199, in run
#     ctx.run(self._callback, *self._args)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_asyncio.py", line 62, in _callback
#     self.emit('error', exc)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_base.py", line 116, in emit
#     self._emit_handle_potential_error(event, args[0] if args else None)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_base.py", line 86, in _emit_handle_potential_error
#     raise error
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/asyncio/tasks.py", line 280, in __step
#     result = coro.send(None)
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 207, in on_message
#     await self.consumer(msg=message)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 909, in async_wrapper
#     retval = await func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 418, in consumer
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 404, in consumer
#     self.recv_immediate_msg_without_reply(msg=_msg)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 461, in recv_immediate_msg_without_reply
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 456, in recv_immediate_msg_without_reply
#     self.node.recv_immediate_msg_without_reply(msg=msg)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 429, in recv_immediate_msg_without_reply
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 400, in recv_immediate_msg_without_reply
#     self.process_message(
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 483, in process_message
#     result = service.process(
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/service/obj_action_service.py", line 26, in process
#     msg.execute_action(node=node, verify_key=verify_key)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/action/run_class_method_action.py", line 111, in execute_action
#     r_arg = node.store[arg.id_at_location]
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/store/store_memory.py", line 74, in __getitem__
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/store/store_memory.py", line 71, in __getitem__
#     return self._objects[key]
# KeyError: <UID: 6e37d64ef6c24d31870aef5be1709a5a>
# [2021-02-24T21:10:03.237259+0000][CRITICAL][logger] <UID: 6e37d64ef6c24d31870aef5be1709a5a>
# [2021-02-24T21:10:03.237589+0000][CRITICAL][logger] <UID: 6e37d64ef6c24d31870aef5be1709a5a>
# [2021-02-24T21:10:03.237894+0000][CRITICAL][logger] <UID: 6e37d64ef6c24d31870aef5be1709a5a>
# [2021-02-24T21:10:03.261031+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: b0562c67351942dfa52ecfb2c58cb699>.
# [2021-02-24T21:10:03.408842+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: b4c175c30a5e4b86b23cbadb0b03248f>.
# [2021-02-24T21:10:04.307149+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __getitem__ error <UID: 5cf929e25fae45c1be3d5ac1c80e792f> <UID: 5cf929e25fae45c1be3d5ac1c80e792f>
# [2021-02-24T21:10:04.307429+0000][CRITICAL][logger] <UID: 5cf929e25fae45c1be3d5ac1c80e792f>
# Exception in callback AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...ac1c80e792f>)>) at /home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_asyncio.py:55
# handle: <Handle AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...ac1c80e792f>)>) at /home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_asyncio.py:55>
# Traceback (most recent call last):
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/nest_asyncio.py", line 199, in run
#     ctx.run(self._callback, *self._args)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_asyncio.py", line 62, in _callback
#     self.emit('error', exc)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_base.py", line 116, in emit
#     self._emit_handle_potential_error(event, args[0] if args else None)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_base.py", line 86, in _emit_handle_potential_error
#     raise error
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/asyncio/tasks.py", line 280, in __step
#     result = coro.send(None)
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 207, in on_message
#     await self.consumer(msg=message)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 909, in async_wrapper
#     retval = await func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 418, in consumer
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 404, in consumer
#     self.recv_immediate_msg_without_reply(msg=_msg)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 461, in recv_immediate_msg_without_reply
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 456, in recv_immediate_msg_without_reply
#     self.node.recv_immediate_msg_without_reply(msg=msg)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 429, in recv_immediate_msg_without_reply
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 400, in recv_immediate_msg_without_reply
#     self.process_message(
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 483, in process_message
#     result = service.process(
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/service/obj_action_service.py", line 26, in process
#     msg.execute_action(node=node, verify_key=verify_key)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/action/run_class_method_action.py", line 111, in execute_action
#     r_arg = node.store[arg.id_at_location]
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/store/store_memory.py", line 74, in __getitem__
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/store/store_memory.py", line 71, in __getitem__
#     return self._objects[key]
# KeyError: <UID: 5cf929e25fae45c1be3d5ac1c80e792f>
# [2021-02-24T21:10:04.307865+0000][CRITICAL][logger] <UID: 5cf929e25fae45c1be3d5ac1c80e792f>
# [2021-02-24T21:10:04.308070+0000][CRITICAL][logger] <UID: 5cf929e25fae45c1be3d5ac1c80e792f>
# [2021-02-24T21:10:04.308264+0000][CRITICAL][logger] <UID: 5cf929e25fae45c1be3d5ac1c80e792f>
# [2021-02-24T21:10:04.326962+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: d904e4d775a745a297b49dc3b1a3c388>.
# [2021-02-24T21:10:04.747997+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: e4e4925a9a45442389c9b49b638249f2>.
# [2021-02-24T21:10:05.104561+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __getitem__ error <UID: c34b6e22e29b4629bd9548aec71b5d06> <UID: c34b6e22e29b4629bd9548aec71b5d06>
# [2021-02-24T21:10:05.104788+0000][CRITICAL][logger] <UID: c34b6e22e29b4629bd9548aec71b5d06>
# [2021-02-24T21:10:05.105197+0000][CRITICAL][logger] <UID: c34b6e22e29b4629bd9548aec71b5d06>
# [2021-02-24T21:10:05.105390+0000][CRITICAL][logger] <UID: c34b6e22e29b4629bd9548aec71b5d06>
# [2021-02-24T21:10:05.105591+0000][CRITICAL][logger] <UID: c34b6e22e29b4629bd9548aec71b5d06>
# Exception in callback AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...8aec71b5d06>)>) at /home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_asyncio.py:55
# handle: <Handle AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...8aec71b5d06>)>) at /home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_asyncio.py:55>
# Traceback (most recent call last):
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/nest_asyncio.py", line 199, in run
#     ctx.run(self._callback, *self._args)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_asyncio.py", line 62, in _callback
#     self.emit('error', exc)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_base.py", line 116, in emit
#     self._emit_handle_potential_error(event, args[0] if args else None)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_base.py", line 86, in _emit_handle_potential_error
#     raise error
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/asyncio/tasks.py", line 280, in __step
#     result = coro.send(None)
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 207, in on_message
#     await self.consumer(msg=message)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 909, in async_wrapper
#     retval = await func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 418, in consumer
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 404, in consumer
#     self.recv_immediate_msg_without_reply(msg=_msg)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 461, in recv_immediate_msg_without_reply
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 456, in recv_immediate_msg_without_reply
#     self.node.recv_immediate_msg_without_reply(msg=msg)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 429, in recv_immediate_msg_without_reply
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 400, in recv_immediate_msg_without_reply
#     self.process_message(
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 483, in process_message
#     result = service.process(
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/service/obj_action_service.py", line 26, in process
#     msg.execute_action(node=node, verify_key=verify_key)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/action/run_class_method_action.py", line 111, in execute_action
#     r_arg = node.store[arg.id_at_location]
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/store/store_memory.py", line 74, in __getitem__
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/store/store_memory.py", line 71, in __getitem__
#     return self._objects[key]
# KeyError: <UID: c34b6e22e29b4629bd9548aec71b5d06>
# [2021-02-24T21:10:05.123861+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: a565c101373f4f01a6dd31275a3649ad>.
# [2021-02-24T21:10:05.845979+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __getitem__ error <UID: 114ea38bcac64283b807bc3448604a8b> <UID: 114ea38bcac64283b807bc3448604a8b>
# [2021-02-24T21:10:05.846206+0000][CRITICAL][logger] <UID: 114ea38bcac64283b807bc3448604a8b>
# Exception in callback AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...c3448604a8b>)>) at /home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_asyncio.py:55
# handle: <Handle AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...c3448604a8b>)>) at /home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_asyncio.py:55>
# Traceback (most recent call last):
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/nest_asyncio.py", line 199, in run
#     ctx.run(self._callback, *self._args)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_asyncio.py", line 62, in _callback
#     self.emit('error', exc)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_base.py", line 116, in emit
#     self._emit_handle_potential_error(event, args[0] if args else None)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_base.py", line 86, in _emit_handle_potential_error
#     raise error
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/asyncio/tasks.py", line 280, in __step
#     result = coro.send(None)
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 207, in on_message
#     await self.consumer(msg=message)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 909, in async_wrapper
#     retval = await func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 418, in consumer
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 404, in consumer
#     self.recv_immediate_msg_without_reply(msg=_msg)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 461, in recv_immediate_msg_without_reply
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 456, in recv_immediate_msg_without_reply
#     self.node.recv_immediate_msg_without_reply(msg=msg)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 429, in recv_immediate_msg_without_reply
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 400, in recv_immediate_msg_without_reply
#     self.process_message(
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 483, in process_message
#     result = service.process(
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/service/obj_action_service.py", line 26, in process
#     msg.execute_action(node=node, verify_key=verify_key)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/action/run_class_method_action.py", line 111, in execute_action
#     r_arg = node.store[arg.id_at_location]
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/store/store_memory.py", line 74, in __getitem__
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/store/store_memory.py", line 71, in __getitem__
#     return self._objects[key]
# KeyError: <UID: 114ea38bcac64283b807bc3448604a8b>
# [2021-02-24T21:10:05.846644+0000][CRITICAL][logger] <UID: 114ea38bcac64283b807bc3448604a8b>
# [2021-02-24T21:10:05.846893+0000][CRITICAL][logger] <UID: 114ea38bcac64283b807bc3448604a8b>
# [2021-02-24T21:10:05.847120+0000][CRITICAL][logger] <UID: 114ea38bcac64283b807bc3448604a8b>
# [2021-02-24T21:10:05.872143+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: 481a421a3af74ec0940444784ef768f2>.
# [2021-02-24T21:10:06.044458+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: 81a2c5e05ffb42a8909838f00813cec9>.
# [2021-02-24T21:10:06.060927+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: f43f2e4957b24c2696bb7db5af8fefcc>.
# [2021-02-24T21:10:06.607580+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __getitem__ error <UID: 652b3fe7952547af821659d1658cb91a> <UID: 652b3fe7952547af821659d1658cb91a>
# [2021-02-24T21:10:06.607801+0000][CRITICAL][logger] <UID: 652b3fe7952547af821659d1658cb91a>
# [2021-02-24T21:10:06.608205+0000][CRITICAL][logger] <UID: 652b3fe7952547af821659d1658cb91a>
# [2021-02-24T21:10:06.608393+0000][CRITICAL][logger] <UID: 652b3fe7952547af821659d1658cb91a>
# [2021-02-24T21:10:06.608586+0000][CRITICAL][logger] <UID: 652b3fe7952547af821659d1658cb91a>
# Exception in callback AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...9d1658cb91a>)>) at /home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_asyncio.py:55
# handle: <Handle AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...9d1658cb91a>)>) at /home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_asyncio.py:55>
# Traceback (most recent call last):
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/nest_asyncio.py", line 199, in run
#     ctx.run(self._callback, *self._args)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_asyncio.py", line 62, in _callback
#     self.emit('error', exc)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_base.py", line 116, in emit
#     self._emit_handle_potential_error(event, args[0] if args else None)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_base.py", line 86, in _emit_handle_potential_error
#     raise error
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/asyncio/tasks.py", line 280, in __step
#     result = coro.send(None)
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 207, in on_message
#     await self.consumer(msg=message)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 909, in async_wrapper
#     retval = await func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 418, in consumer
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 404, in consumer
#     self.recv_immediate_msg_without_reply(msg=_msg)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 461, in recv_immediate_msg_without_reply
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 456, in recv_immediate_msg_without_reply
#     self.node.recv_immediate_msg_without_reply(msg=msg)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 429, in recv_immediate_msg_without_reply
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 400, in recv_immediate_msg_without_reply
#     self.process_message(
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 483, in process_message
#     result = service.process(
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/service/obj_action_service.py", line 26, in process
#     msg.execute_action(node=node, verify_key=verify_key)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/action/run_class_method_action.py", line 111, in execute_action
#     r_arg = node.store[arg.id_at_location]
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/store/store_memory.py", line 74, in __getitem__
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/store/store_memory.py", line 71, in __getitem__
#     return self._objects[key]
# KeyError: <UID: 652b3fe7952547af821659d1658cb91a>
# [2021-02-24T21:10:06.628392+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: cd7d5898f2974061bfb88511d28b7dae>.
# [2021-02-24T21:10:07.321692+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __getitem__ error <UID: 03695dd007744312b5a7674941ecdece> <UID: 03695dd007744312b5a7674941ecdece>
# [2021-02-24T21:10:07.321966+0000][CRITICAL][logger] <UID: 03695dd007744312b5a7674941ecdece>
# [2021-02-24T21:10:07.322372+0000][CRITICAL][logger] <UID: 03695dd007744312b5a7674941ecdece>
# Exception in callback AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...74941ecdece>)>) at /home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_asyncio.py:55
# handle: <Handle AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...74941ecdece>)>) at /home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_asyncio.py:55>
# Traceback (most recent call last):
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/nest_asyncio.py", line 199, in run
#     ctx.run(self._callback, *self._args)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_asyncio.py", line 62, in _callback
#     self.emit('error', exc)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_base.py", line 116, in emit
#     self._emit_handle_potential_error(event, args[0] if args else None)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_base.py", line 86, in _emit_handle_potential_error
#     raise error
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/asyncio/tasks.py", line 280, in __step
#     result = coro.send(None)
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 207, in on_message
#     await self.consumer(msg=message)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 909, in async_wrapper
#     retval = await func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 418, in consumer
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 404, in consumer
#     self.recv_immediate_msg_without_reply(msg=_msg)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 461, in recv_immediate_msg_without_reply
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 456, in recv_immediate_msg_without_reply
#     self.node.recv_immediate_msg_without_reply(msg=msg)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 429, in recv_immediate_msg_without_reply
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 400, in recv_immediate_msg_without_reply
#     self.process_message(
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 483, in process_message
#     result = service.process(
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/service/obj_action_service.py", line 26, in process
#     msg.execute_action(node=node, verify_key=verify_key)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/action/run_class_method_action.py", line 111, in execute_action
#     r_arg = node.store[arg.id_at_location]
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/store/store_memory.py", line 74, in __getitem__
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/store/store_memory.py", line 71, in __getitem__
#     return self._objects[key]
# KeyError: <UID: 03695dd007744312b5a7674941ecdece>
# [2021-02-24T21:10:07.322564+0000][CRITICAL][logger] <UID: 03695dd007744312b5a7674941ecdece>
# [2021-02-24T21:10:07.322765+0000][CRITICAL][logger] <UID: 03695dd007744312b5a7674941ecdece>
# [2021-02-24T21:10:07.345688+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: 44ebe723575345a588c3cbfdeff6d82c>.
# [2021-02-24T21:10:07.396241+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: 22aa3b03631b487daecf1e3be9f8a0a9>.
# [2021-02-24T21:10:07.412454+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: f2ccece4ccc54a84a5818fe1f532f248>.
# [2021-02-24T21:10:08.112231+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __getitem__ error <UID: a05143e441fc405e850ec28fd7311a7b> <UID: a05143e441fc405e850ec28fd7311a7b>
# Exception in callback AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...28fd7311a7b>)>) at /home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_asyncio.py:55
# handle: <Handle AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...28fd7311a7b>)>) at /home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_asyncio.py:55>
# Traceback (most recent call last):
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/nest_asyncio.py", line 199, in run
#     ctx.run(self._callback, *self._args)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_asyncio.py", line 62, in _callback
#     self.emit('error', exc)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_base.py", line 116, in emit
#     self._emit_handle_potential_error(event, args[0] if args else None)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_base.py", line 86, in _emit_handle_potential_error
#     raise error
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/asyncio/tasks.py", line 280, in __step
#     result = coro.send(None)
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 207, in on_message
#     await self.consumer(msg=message)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 909, in async_wrapper
#     retval = await func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 418, in consumer
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 404, in consumer
#     self.recv_immediate_msg_without_reply(msg=_msg)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 461, in recv_immediate_msg_without_reply
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 456, in recv_immediate_msg_without_reply
#     self.node.recv_immediate_msg_without_reply(msg=msg)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 429, in recv_immediate_msg_without_reply
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 400, in recv_immediate_msg_without_reply
#     self.process_message(
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 483, in process_message
#     result = service.process(
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
# ...
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 461, in recv_immediate_msg_without_reply
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 456, in recv_immediate_msg_without_reply
#     self.node.recv_immediate_msg_without_reply(msg=msg)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 429, in recv_immediate_msg_without_reply
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 400, in recv_immediate_msg_without_reply
#     self.process_message(
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 483, in process_message
#     result = service.process(
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/service/obj_action_service.py", line 26, in process
#     msg.execute_action(node=node, verify_key=verify_key)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/action/run_class_method_action.py", line 111, in execute_action
#     r_arg = node.store[arg.id_at_location]
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/store/store_memory.py", line 74, in __getitem__
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/store/store_memory.py", line 71, in __getitem__
#     return self._objects[key]
# KeyError: <UID: 5bb999a80d474fdab360410c18799a48>
# [2021-02-24T21:14:33.648825+0000][CRITICAL][logger] <UID: 5bb999a80d474fdab360410c18799a48>
# [2021-02-24T21:14:33.649090+0000][CRITICAL][logger] <UID: 5bb999a80d474fdab360410c18799a48>
# [2021-02-24T21:14:33.649365+0000][CRITICAL][logger] <UID: 5bb999a80d474fdab360410c18799a48>
# [2021-02-24T21:14:33.672264+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: 6e9da072a8c747dea423b0a77ee5629f>.
# [2021-02-24T21:14:34.055964+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: 0e953391134e492a8d66c8b2adfe71f7>.
# [2021-02-24T21:14:34.336240+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __getitem__ error <UID: 41d5593b0b7f4c6198cbee33091bcc8d> <UID: 41d5593b0b7f4c6198cbee33091bcc8d>
# [2021-02-24T21:14:34.336450+0000][CRITICAL][logger] <UID: 41d5593b0b7f4c6198cbee33091bcc8d>
# Exception in callback AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...e33091bcc8d>)>) at /home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_asyncio.py:55
# handle: <Handle AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...e33091bcc8d>)>) at /home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_asyncio.py:55>
# Traceback (most recent call last):
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/nest_asyncio.py", line 199, in run
#     ctx.run(self._callback, *self._args)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_asyncio.py", line 62, in _callback
#     self.emit('error', exc)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_base.py", line 116, in emit
#     self._emit_handle_potential_error(event, args[0] if args else None)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_base.py", line 86, in _emit_handle_potential_error
#     raise error
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/asyncio/tasks.py", line 280, in __step
#     result = coro.send(None)
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 207, in on_message
#     await self.consumer(msg=message)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 909, in async_wrapper
#     retval = await func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 418, in consumer
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 404, in consumer
#     self.recv_immediate_msg_without_reply(msg=_msg)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 461, in recv_immediate_msg_without_reply
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 456, in recv_immediate_msg_without_reply
#     self.node.recv_immediate_msg_without_reply(msg=msg)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 429, in recv_immediate_msg_without_reply
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 400, in recv_immediate_msg_without_reply
#     self.process_message(
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 483, in process_message
#     result = service.process(
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/service/obj_action_service.py", line 26, in process
#     msg.execute_action(node=node, verify_key=verify_key)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/action/run_class_method_action.py", line 111, in execute_action
#     r_arg = node.store[arg.id_at_location]
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/store/store_memory.py", line 74, in __getitem__
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/store/store_memory.py", line 71, in __getitem__
#     return self._objects[key]
# KeyError: <UID: 41d5593b0b7f4c6198cbee33091bcc8d>
# [2021-02-24T21:14:34.336809+0000][CRITICAL][logger] <UID: 41d5593b0b7f4c6198cbee33091bcc8d>
# [2021-02-24T21:14:34.336980+0000][CRITICAL][logger] <UID: 41d5593b0b7f4c6198cbee33091bcc8d>
# [2021-02-24T21:14:34.337156+0000][CRITICAL][logger] <UID: 41d5593b0b7f4c6198cbee33091bcc8d>
# [2021-02-24T21:14:34.354048+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: 11d42da742b24a90ac74d4007856839a>.
# [2021-02-24T21:14:35.022034+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __getitem__ error <UID: 17d48f976d2343a392e0ebe19119b02d> <UID: 17d48f976d2343a392e0ebe19119b02d>
# [2021-02-24T21:14:35.022910+0000][CRITICAL][logger] <UID: 17d48f976d2343a392e0ebe19119b02d>
# Exception in callback AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...be19119b02d>)>) at /home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_asyncio.py:55
# handle: <Handle AsyncIOEventEmitter._emit_run.<locals>._callback(<Task finishe...be19119b02d>)>) at /home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_asyncio.py:55>
# Traceback (most recent call last):
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/nest_asyncio.py", line 199, in run
#     ctx.run(self._callback, *self._args)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_asyncio.py", line 62, in _callback
#     self.emit('error', exc)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_base.py", line 116, in emit
#     self._emit_handle_potential_error(event, args[0] if args else None)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/pyee/_base.py", line 86, in _emit_handle_potential_error
#     raise error
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/asyncio/tasks.py", line 280, in __step
#     result = coro.send(None)
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 207, in on_message
#     await self.consumer(msg=message)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 909, in async_wrapper
#     retval = await func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 418, in consumer
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 404, in consumer
#     self.recv_immediate_msg_without_reply(msg=_msg)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 461, in recv_immediate_msg_without_reply
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/grid/connections/webrtc.py", line 456, in recv_immediate_msg_without_reply
#     self.node.recv_immediate_msg_without_reply(msg=msg)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 429, in recv_immediate_msg_without_reply
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 400, in recv_immediate_msg_without_reply
#     self.process_message(
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/node.py", line 483, in process_message
#     result = service.process(
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/service/obj_action_service.py", line 26, in process
#     msg.execute_action(node=node, verify_key=verify_key)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/node/common/action/run_class_method_action.py", line 111, in execute_action
#     r_arg = node.store[arg.id_at_location]
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/syft_decorator_impl.py", line 31, in wrapper
#     return function(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/decorators/typecheck.py", line 119, in decorator
#     return typechecked(decorated)(*args, **kwargs)
#   File "/home/tom/anaconda3/envs/pyv_duet/lib/python3.8/site-packages/typeguard/__init__.py", line 891, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/store/store_memory.py", line 74, in __getitem__
#     traceback_and_raise(e)
#   File "/home/tom/Documents/OM/PySyft/src/syft/logger.py", line 59, in traceback_and_raise
#     raise e
#   File "/home/tom/Documents/OM/PySyft/src/syft/core/store/store_memory.py", line 71, in __getitem__
#     return self._objects[key]
# KeyError: <UID: 17d48f976d2343a392e0ebe19119b02d>
# [2021-02-24T21:14:35.023525+0000][CRITICAL][logger] <UID: 17d48f976d2343a392e0ebe19119b02d>
# [2021-02-24T21:14:35.023727+0000][CRITICAL][logger] <UID: 17d48f976d2343a392e0ebe19119b02d>
# [2021-02-24T21:14:35.024365+0000][CRITICAL][logger] <UID: 17d48f976d2343a392e0ebe19119b02d>
# [2021-02-24T21:14:35.039050+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: 70788d956b174c7c805dc44ec998a443>.
# [2021-02-24T21:14:35.237415+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: ff2e594a41c24bd9a8e9b81d6c66c1eb>.
# [2021-02-24T21:14:35.251934+0000][CRITICAL][logger] <class 'syft.core.store.store_memory.MemoryStore'> __delitem__ error <UID: 4b35958ecbe94dac8db4bcb7fbe7f876>.
